# %% [markdown]
# # importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # loading data

# %%
df=pd.read_csv('C:\\Users\\saran\\Downloads\\Heart_Disease_Prediction.csv')

# %%
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %% [markdown]
# # checking null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest pain type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholesterol              270 non-null    int64
#  5   FBS over 120             270 non-null    int64
#  6   EKG results              270 non-null    int64
#  7   Max HR                   270 non-null    int64
#  8   Exercise angina          270 non-null    int64
#  9   ST depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of vessels fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
#  13  Heart Disease            270 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # count of no of heart disease patient

# %%
sns.countplot(x=df['Heart Disease'])
# Out:
# <AxesSubplot:xlabel='Heart Disease', ylabel='count'>

# %% [markdown]
# # heart disease patient classified based on age

# %%
sns.scatterplot(data=df,x='Age',y='Heart Disease')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Heart Disease'>

# %% [markdown]
# # heart disease patient classified based on cholesterol

# %%
plt.figure(figsize=(5,2),dpi=200)
sns.scatterplot(data=df,x='Cholesterol',y='Heart Disease')
# Out:
# <AxesSubplot:xlabel='Cholesterol', ylabel='Heart Disease'>

# %% [markdown]
# # heart disease patient classified based on BP

# %%
plt.figure(figsize=(5,2),dpi=200)
sns.scatterplot(data=df,x='BP',y='Heart Disease')
# Out:
# <AxesSubplot:xlabel='BP', ylabel='Heart Disease'>

# %% [markdown]
# # ages of people classified on heart disease

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df,x='Age',hue='Heart Disease')
plt.xticks(rotation=90);

# %% [markdown]
# # heart disease patient classified based on Chest pain type

# %%
sns.countplot(data=df,x='Chest pain type',hue='Heart Disease')
# Out:
# <AxesSubplot:xlabel='Chest pain type', ylabel='count'>

# %% [markdown]
# # Feature Distribution

# %% [markdown]
# # relation between BP and Cholesterol

# %%
sns.scatterplot(data=df,x='BP',y='Cholesterol',hue='Heart Disease')
# Out:
# <AxesSubplot:xlabel='BP', ylabel='Cholesterol'>

# %% [markdown]
# # clearly for maximum patient BP is in range (100,160) and cholesterol is in range (150,300)

# %% [markdown]
# # relation between Age and ST depression

# %%
sns.scatterplot(data=df,x='Age',y='ST depression',hue='Heart Disease')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='ST depression'>

# %% [markdown]
# # people with age above 40 and St depression level more than 1 are more likely to have Heart disease

# %% [markdown]
# # relation between Age and Slope of ST

# %%
sns.scatterplot(data=df,x='Age',y='Slope of ST',hue='Heart Disease')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Slope of ST'>

# %% [markdown]
# # If slope of ST is equal to 2 then the person is more likely to have health disease and it is more likely to be present in ppeople of age greater than 40

# %% [markdown]
# # relation between Age and Thallium

# %%
sns.scatterplot(data=df,x='Age',y='Thallium',hue='Heart Disease')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Thallium'>

# %% [markdown]
# # people with thallium equal to 3 are less prone to health disease whereas people with thallium equal to 7 are more prone to Health disease

# %% [markdown]
# # Data segregation

# %%
X=df.drop('Heart Disease',axis=1)
y=df['Heart Disease']

# %% [markdown]
# # correlation between columns

# %%
X.corr()
# Out:
#                               Age       Sex  Chest pain type        BP  \
# Age                      1.000000 -0.094401         0.096920  0.273053
# Sex                     -0.094401  1.000000         0.034636 -0.062693
# Chest pain type          0.096920  0.034636         1.000000 -0.043196
# BP                       0.273053 -0.062693        -0.043196  1.000000
# Cholesterol              0.220056 -0.201647         0.090465  0.173019
# FBS over 120             0.123458  0.042140        -0.098537  0.155681
# EKG results              0.128171  0.039253         0.074325  0.116157
# Max HR                  -0.402215 -0.076101        -0.317682 -0.039136
# Exercise angina          0.098297  0.180022         0.353160  0.082793
# ST depression            0.194234  0.097412         0.167244  0.222800
# Slope of ST              0.159774  0.050545         0.136900  0.142472
# Number of vessels fluro  0.356081  0.086830         0.225890  0.085697
# ...

# %% [markdown]
# # Heatmap to visualise correlation between columns

# %%
sns.heatmap(X.corr())
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %% [markdown]
# # Data splitting

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=49)

# %% [markdown]
# # scaling data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %% [markdown]
# # fitting and transforming data

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %% [markdown]
# # Logistic Regression model

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model=LogisticRegression(max_iter=5000,solver='saga')

# %% [markdown]
# # Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
l1_ratio = np.linspace(0, 1, 20)
C = np.logspace(-3, 3, 10)
param_grid=[{'penalty':['l1','l2'],'C':C},{'penalty':['elasticnet'],'l1_ratio':l1_ratio,'C':C}]
log_grid_model=GridSearchCV(estimator=log_model,param_grid=param_grid)

# %% [markdown]
# # fitting data

# %%
log_grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=LogisticRegression(max_iter=5000, solver='saga'),
#              param_grid=[{'C': array([1.00000000e-03, 4.64158883e-03, 2.15443469e-02, 1.00000000e-01,
#        4.64158883e-01, 2.15443469e+00, 1.00000000e+01, 4.64158883e+01,
#        2.15443469e+02, 1.00000000e+03]),
#                           'penalty': ['l1', 'l2']},
#                          {'C': array([1.00000000e-03, 4.64158883e-03, 2.15443469e-02, 1.00000000e-01,
#        4.64158883e-01, 2.15443469e+00, 1.00000000e+01, 4.64158883e+01,
#        2.15443469e+02, 1.00000000e+03]),
#                           'l1_ratio': array([0.        , 0.05263158, 0.10526316, 0.15789474, 0.21052632,
#        0.26315789, 0.31578947, 0.36842105, 0.42105263, 0.47368421,
#        0.52631579, 0.57894737, 0.63157895, 0.68421053, 0.73684211,
#        0.78947368, 0.84210526, 0.89473684, 0.94736842, 1.        ]),
#                           'penalty': ['elasticnet']}])

# %% [markdown]
# # predicting output

# %%
log_grid_model_pred=log_grid_model.predict(X_test)

# %% [markdown]
# # accuracy,confusion matrix and classification report

# %%
from sklearn.metrics import accuracy_score,plot_confusion_matrix,classification_report

# %%
log_grid_model_acc=accuracy_score(y_test,log_model_pred)

# %%
log_grid_model_acc
# Out:
# 0.8518518518518519

# %%
print(classification_report(y_test,log_grid_model_pred))
# Out:
#               precision    recall  f1-score   support
#
#      Absence       0.81      0.90      0.85        39
#     Presence       0.89      0.81      0.85        42
#
#     accuracy                           0.85        81
#    macro avg       0.85      0.85      0.85        81
# weighted avg       0.86      0.85      0.85        81

# %%
plot_confusion_matrix(estimator=log_grid_model,X=X_test,y_true=y_test)

# %% [markdown]
# # plotting precision recall curve and plotting roc curve

# %%
from sklearn.metrics import plot_precision_recall_curve,plot_roc_curve

# %%
plot_precision_recall_curve(log_grid_model,X_test,y_test)

# %%
plot_roc_curve(log_grid_model,X_test,y_test)
plt.savefig()

# %%
from sklearn.metrics import roc_auc_score

# %%
y_prob=log_grid_model.predict_proba(X_test)
roc_auc_score(y_test,y_prob[:,1])
# Out:
# 0.931013431013431

# %% [markdown]
# # model 2- Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
Dt_acc=[]
for i in range(1,10):
    Dt=DecisionTreeClassifier(criterion='entropy',max_depth=i)
    Dt.fit(X_train,y_train)
    Dt_pred=Dt.predict(X_test)
    accuracy=accuracy_score(y_test,Dt_pred)
    Dt_acc.append(accuracy)

# %%
Dt_acc
# Out:
# [0.7654320987654321,
#  0.7530864197530864,
#  0.7777777777777778,
#  0.8148148148148148,
#  0.8395061728395061,
#  0.8024691358024691,
#  0.8271604938271605,
#  0.8395061728395061,
#  0.8024691358024691]

# %%
plt.plot(range(1,10),Dt_acc)
plt.xlabel('max_depth')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %% [markdown]
# # clearly accuracy is highest at max depth of 5

# %%
Dt=DecisionTreeClassifier(max_depth=5)

# %%
param_grid = {
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 5, 10],
    'criterion': ['gini', 'entropy'],
    'max_features': [None, 'sqrt', 'log2']
}
Dt_grid_model=GridSearchCV(estimator=Dt,param_grid=param_grid)

# %%
Dt_grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(max_depth=5),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 5, 10],
#                          'min_samples_split': [2, 5, 10, 20]})

# %%
Dt_grid_model.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=5, max_features='log2', min_samples_leaf=2,
#                        min_samples_split=5)

# %%
Dt_grid_model_pred=Dt_grid_model.predict(X_test)

# %% [markdown]
# # accuracy,confusion matrix and classification report

# %%
Dt_acc=accuracy_score(y_test,Dt_pred)

# %%
Dt_acc
# Out:
# 0.8024691358024691

# %%
plot_confusion_matrix(estimator=Dt_grid_model,X=X_test,y_true=y_test)

# %%
print(classification_report(y_test,Dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#      Absence       0.74      0.90      0.81        39
#     Presence       0.88      0.71      0.79        42
#
#     accuracy                           0.80        81
#    macro avg       0.81      0.81      0.80        81
# weighted avg       0.82      0.80      0.80        81

# %% [markdown]
# # plotting precision recall curve and plotting roc curve

# %%
 plot_precision_recall_curve(Dt_grid_model,X_test,y_test)

# %%
plot_roc_curve(Dt_grid_model,X_test,y_test)

# %%
y_prob=Dt_grid_model.predict_proba(X_test)
roc_auc_score(y_test,y_prob[:,1])
# Out:
# 0.8751526251526252

# %% [markdown]
# # model 3- Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc_acc=[]
for i in range(1,10):
    rfc=RandomForestClassifier(criterion='entropy',max_depth=i)
    rfc.fit(X_train,y_train)
    rfc_pred=rfc.predict(X_test)
    accuracy=accuracy_score(y_test,rfc_pred)
    rfc_acc.append(accuracy)

# %%
rfc_acc
# Out:
# [0.7901234567901234,
#  0.8271604938271605,
#  0.8271604938271605,
#  0.8024691358024691,
#  0.7777777777777778,
#  0.8395061728395061,
#  0.8395061728395061,
#  0.8148148148148148,
#  0.8148148148148148]

# %%
plt.plot(range(1,10),rfc_acc)
plt.xlabel('max_depth')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %% [markdown]
# # clearly accuracy is highest at max depth of 6

# %%
rfc=RandomForestClassifier(criterion='entropy',max_depth=6)

# %%
param_grid = {
    'n_estimators': [10, 20, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 5],
    'max_features': ['sqrt', 'log2'],
    'bootstrap': [True, False]
}
rfc_grid_model=GridSearchCV(estimator=rfc,param_grid=param_grid)

# %%
rfc_grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(criterion='entropy', max_depth=6),
#              param_grid={'bootstrap': [True, False],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 5],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 20, 50]})

# %%
rfc_pred=rfc.predict(X_test)

# %%
rfc_acc=accuracy_score(y_test,rfc_pred)

# %%
rfc_acc
# Out:
# 0.7901234567901234

# %%
plot_confusion_matrix(estimator=rfc_grid_model,X=X_test,y_true=y_test)

# %%
    print(classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#      Absence       0.74      0.87      0.80        39
#     Presence       0.86      0.71      0.78        42
#
#     accuracy                           0.79        81
#    macro avg       0.80      0.79      0.79        81
# weighted avg       0.80      0.79      0.79        81

# %% [markdown]
# # plotting precision recall curve and plotting roc curve

# %%
plot_precision_recall_curve(rfc_grid_model,X_test,y_test)

# %%
plot_roc_curve(rfc_grid_model,X_test,y_test)

# %% [markdown]
# # Conclusion

# %% [markdown]
# # Nearly all the 3 models i.e. (LogisticRegression,DecisionTreeClassifier,RandomForestClassifier) has performed certainly well but logistic regression has outerformed other model in both accuracy and f1 score,since f1 score of logistic regression is 0.85 wheras other model have f1 score nearly 0.8 therefore the best model for estimating heart disease is Logistic Regression

# %% [markdown]
# # Clearly from ROC curve we can easily say that logistic regression and Random Forest has outperformed Decision Tree classifier with Area under cure equals 0.93

# %%
# Model Deployment

# %%
from joblib import dump,load

# %%
dump(log_grid_model,'log_model.jobib')
# Out:
# ['log_model.jobib']
